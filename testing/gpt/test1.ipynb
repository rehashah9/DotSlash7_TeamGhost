# %%
# %pip install vanna
# %pip install 'vanna[postgres]'
# Out:
# Requirement already satisfied: vanna in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (0.0.35)
# Requirement already satisfied: requests in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from vanna) (2.31.0)
# Requirement already satisfied: tabulate in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from vanna) (0.9.0)
# Requirement already satisfied: plotly in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from vanna) (5.18.0)
# Requirement already satisfied: pandas in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from vanna) (2.2.0)
# Requirement already satisfied: sqlparse in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from vanna) (0.4.4)
# Requirement already satisfied: kaleido in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from vanna) (0.2.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from pandas->vanna) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from pandas->vanna) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from pandas->vanna) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from pandas->vanna) (2023.4)
# Requirement already satisfied: tenacity>=6.2.0 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from plotly->vanna) (8.2.3)
# Requirement already satisfied: packaging in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from plotly->vanna) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from requests->vanna) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from requests->vanna) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from requests->vanna) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from requests->vanna) (2023.11.17)
# Requirement already satisfied: six>=1.5 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->vanna) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: vanna[postgres] in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (0.0.35)
# Requirement already satisfied: requests in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from vanna[postgres]) (2.31.0)
# Requirement already satisfied: tabulate in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from vanna[postgres]) (0.9.0)
# Requirement already satisfied: plotly in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from vanna[postgres]) (5.18.0)
# Requirement already satisfied: pandas in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from vanna[postgres]) (2.2.0)
# Requirement already satisfied: sqlparse in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from vanna[postgres]) (0.4.4)
# Requirement already satisfied: kaleido in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from vanna[postgres]) (0.2.1)
# Collecting psycopg2 (from vanna[postgres])
#   Downloading psycopg2-2.9.9.tar.gz (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 1.1 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: db-dtypes in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from vanna[postgres]) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from db-dtypes->vanna[postgres]) (23.2)
# Requirement already satisfied: pyarrow>=3.0.0 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from db-dtypes->vanna[postgres]) (14.0.2)
# Requirement already satisfied: numpy>=1.16.6 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from db-dtypes->vanna[postgres]) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from pandas->vanna[postgres]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from pandas->vanna[postgres]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from pandas->vanna[postgres]) (2023.4)
# Requirement already satisfied: tenacity>=6.2.0 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from plotly->vanna[postgres]) (8.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from requests->vanna[postgres]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from requests->vanna[postgres]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from requests->vanna[postgres]) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from requests->vanna[postgres]) (2023.11.17)
# Requirement already satisfied: six>=1.5 in /home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->vanna[postgres]) (1.16.0)
# Building wheels for collected packages: psycopg2
#   Building wheel for psycopg2 (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [38 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-cpython-310
#       creating build/lib.linux-x86_64-cpython-310/psycopg2
#       copying lib/sql.py -> build/lib.linux-x86_64-cpython-310/psycopg2
#       copying lib/_range.py -> build/lib.linux-x86_64-cpython-310/psycopg2
#       copying lib/__init__.py -> build/lib.linux-x86_64-cpython-310/psycopg2
#       copying lib/_ipaddress.py -> build/lib.linux-x86_64-cpython-310/psycopg2
#       copying lib/errors.py -> build/lib.linux-x86_64-cpython-310/psycopg2
#       copying lib/pool.py -> build/lib.linux-x86_64-cpython-310/psycopg2
#       copying lib/extras.py -> build/lib.linux-x86_64-cpython-310/psycopg2
#       copying lib/errorcodes.py -> build/lib.linux-x86_64-cpython-310/psycopg2
#       copying lib/extensions.py -> build/lib.linux-x86_64-cpython-310/psycopg2
#       copying lib/_json.py -> build/lib.linux-x86_64-cpython-310/psycopg2
#       copying lib/tz.py -> build/lib.linux-x86_64-cpython-310/psycopg2
#       running build_ext
#       building 'psycopg2._psycopg' extension
#       creating build/temp.linux-x86_64-cpython-310
#       creating build/temp.linux-x86_64-cpython-310/psycopg
#       x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC "-DPSYCOPG_VERSION=2.9.9 (dt dec pq3 ext lo64)" -DPSYCOPG_DEBUG=1 -DPG_VERSION_NUM=140010 -DHAVE_LO64=1 -DPSYCOPG_DEBUG=1 -I/home/imabhisht/.pyenv/versions/lookover-cg/include -I/usr/include/python3.10 -I. -I/usr/include/postgresql -I/usr/include/postgresql/14/server -I/usr/include/libxml2 -c psycopg/adapter_asis.c -o build/temp.linux-x86_64-cpython-310/psycopg/adapter_asis.o -Wdeclaration-after-statement
#       In file included from psycopg/adapter_asis.c:28:
#       ./psycopg/psycopg.h:36:10: fatal error: libpq-fe.h: No such file or directory
#          36 | #include <libpq-fe.h>
#             |          ^~~~~~~~~~~~
#       compilation terminated.
#
#       It appears you are missing some prerequisite to build the package from source.
#
#       You may install a binary package by installing 'psycopg2-binary' from PyPI.
#       If you want to install psycopg2 from source, please install the packages
#       required for the build and try again.
#
#       For further information please check the 'doc/src/install.rst' file (also at
#       <https://www.psycopg.org/docs/install.html>).
#
#       error: command '/usr/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for psycopg2
#   Running setup.py clean for psycopg2
# Failed to build psycopg2
# ERROR: Could not build wheels for psycopg2, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import vanna
from vanna.remote import VannaDefault

# %%
vn = VannaDefault(model='thelook', api_key='ed25c6609b0d43b4a09dfbb3e878bfbf')

# %%
vn.connect_to_postgres(host='127.0.0.1', dbname='steampipe', user='steampipe', password='7e77_4db6_a095', port='9193')

# %%
df_information_schema = vn.run_sql("SELECT * FROM INFORMATION_SCHEMA.COLUMNS")
plan = vn.get_training_plan_generic(df_information_schema)
print(plan)
vn.train(plan=plan)
# Out:
# Train on Information Schema: steampipe.pg_catalog pg_proc
# Train on Information Schema: steampipe.pg_catalog pg_type
# Train on Information Schema: steampipe.pg_catalog pg_attribute
# Train on Information Schema: steampipe.pg_catalog pg_class
# Train on Information Schema: steampipe.pg_catalog pg_attrdef
# Train on Information Schema: steampipe.pg_catalog pg_constraint
# Train on Information Schema: steampipe.pg_catalog pg_inherits
# Train on Information Schema: steampipe.pg_catalog pg_index
# Train on Information Schema: steampipe.pg_catalog pg_operator
# Train on Information Schema: steampipe.pg_catalog pg_opfamily
# Train on Information Schema: steampipe.pg_catalog pg_opclass
# Train on Information Schema: steampipe.pg_catalog pg_am
# Train on Information Schema: steampipe.pg_catalog pg_amop
# Train on Information Schema: steampipe.pg_catalog pg_amproc
# Train on Information Schema: steampipe.pg_catalog pg_language
# Train on Information Schema: steampipe.pg_catalog pg_largeobject_metadata
# Train on Information Schema: steampipe.pg_catalog pg_aggregate
# Train on Information Schema: steampipe.pg_catalog pg_statistic_ext
# Train on Information Schema: steampipe.pg_catalog pg_rewrite
# Train on Information Schema: steampipe.pg_catalog pg_trigger
# Train on Information Schema: steampipe.pg_catalog pg_event_trigger
# Train on Information Schema: steampipe.pg_catalog pg_description
# Train on Information Schema: steampipe.pg_catalog pg_cast
# Train on Information Schema: steampipe.pg_catalog pg_enum
# Train on Information Schema: steampipe.pg_catalog pg_namespace
# Train on Information Schema: steampipe.pg_catalog pg_conversion
# Train on Information Schema: steampipe.pg_catalog pg_depend
# Train on Information Schema: steampipe.pg_catalog pg_database
# Train on Information Schema: steampipe.pg_catalog pg_db_role_setting
# Train on Information Schema: steampipe.pg_catalog pg_tablespace
# Train on Information Schema: steampipe.pg_catalog pg_auth_members
# Train on Information Schema: steampipe.pg_catalog pg_shdepend
# Train on Information Schema: steampipe.pg_catalog pg_shdescription
# Train on Information Schema: steampipe.pg_catalog pg_ts_config
# Train on Information Schema: steampipe.pg_catalog pg_ts_config_map
# Train on Information Schema: steampipe.pg_catalog pg_ts_dict
# Train on Information Schema: steampipe.pg_catalog pg_ts_parser
# Train on Information Schema: steampipe.pg_catalog pg_ts_template
# Train on Information Schema: steampipe.pg_catalog pg_extension
# Train on Information Schema: steampipe.pg_catalog pg_foreign_data_wrapper
# Train on Information Schema: steampipe.pg_catalog pg_foreign_server
# Train on Information Schema: steampipe.pg_catalog pg_foreign_table
# Train on Information Schema: steampipe.pg_catalog pg_policy
# Train on Information Schema: steampipe.pg_catalog pg_replication_origin
# Train on Information Schema: steampipe.pg_catalog pg_default_acl
# Train on Information Schema: steampipe.pg_catalog pg_init_privs
# Train on Information Schema: steampipe.pg_catalog pg_seclabel
# Train on Information Schema: steampipe.pg_catalog pg_shseclabel
# Train on Information Schema: steampipe.pg_catalog pg_collation
# Train on Information Schema: steampipe.pg_catalog pg_partitioned_table
# Train on Information Schema: steampipe.pg_catalog pg_range
# Train on Information Schema: steampipe.pg_catalog pg_transform
# Train on Information Schema: steampipe.pg_catalog pg_sequence
# Train on Information Schema: steampipe.pg_catalog pg_publication
# Train on Information Schema: steampipe.pg_catalog pg_publication_rel
# Train on Information Schema: steampipe.pg_catalog pg_subscription_rel
# Train on Information Schema: steampipe.pg_catalog pg_roles
# Train on Information Schema: steampipe.pg_catalog pg_group
# Train on Information Schema: steampipe.pg_catalog pg_user
# Train on Information Schema: steampipe.pg_catalog pg_policies
# Train on Information Schema: steampipe.pg_catalog pg_rules
# Train on Information Schema: steampipe.pg_catalog pg_views
# Train on Information Schema: steampipe.pg_catalog pg_tables
# Train on Information Schema: steampipe.pg_catalog pg_matviews
# Train on Information Schema: steampipe.pg_catalog pg_indexes
# Train on Information Schema: steampipe.pg_catalog pg_sequences
# Train on Information Schema: steampipe.pg_catalog pg_stats
# Train on Information Schema: steampipe.pg_catalog pg_stats_ext
# Train on Information Schema: steampipe.pg_catalog pg_stats_ext_exprs
# Train on Information Schema: steampipe.pg_catalog pg_publication_tables
# Train on Information Schema: steampipe.pg_catalog pg_locks
# Train on Information Schema: steampipe.pg_catalog pg_cursors
# Train on Information Schema: steampipe.pg_catalog pg_available_extensions
# Train on Information Schema: steampipe.pg_catalog pg_available_extension_versions
# Train on Information Schema: steampipe.pg_catalog pg_prepared_xacts
# Train on Information Schema: steampipe.pg_catalog pg_prepared_statements
# Train on Information Schema: steampipe.pg_catalog pg_seclabels
# Train on Information Schema: steampipe.pg_catalog pg_settings
# Train on Information Schema: steampipe.pg_catalog pg_timezone_abbrevs
# Train on Information Schema: steampipe.pg_catalog pg_timezone_names
# Train on Information Schema: steampipe.pg_catalog pg_stat_all_tables
# Train on Information Schema: steampipe.pg_catalog pg_stat_xact_all_tables
# Train on Information Schema: steampipe.pg_catalog pg_stat_sys_tables
# Train on Information Schema: steampipe.pg_catalog pg_stat_xact_sys_tables
# Train on Information Schema: steampipe.pg_catalog pg_stat_user_tables
# Train on Information Schema: steampipe.pg_catalog pg_stat_xact_user_tables
# Train on Information Schema: steampipe.pg_catalog pg_statio_all_tables
# Train on Information Schema: steampipe.pg_catalog pg_statio_sys_tables
# Train on Information Schema: steampipe.pg_catalog pg_statio_user_tables
# Train on Information Schema: steampipe.pg_catalog pg_stat_all_indexes
# Train on Information Schema: steampipe.pg_catalog pg_stat_sys_indexes
# Train on Information Schema: steampipe.pg_catalog pg_stat_user_indexes
# Train on Information Schema: steampipe.pg_catalog pg_statio_all_indexes
# Train on Information Schema: steampipe.pg_catalog pg_statio_sys_indexes
# Train on Information Schema: steampipe.pg_catalog pg_statio_user_indexes
# Train on Information Schema: steampipe.pg_catalog pg_statio_all_sequences
# Train on Information Schema: steampipe.pg_catalog pg_statio_sys_sequences
# Train on Information Schema: steampipe.pg_catalog pg_statio_user_sequences
# Train on Information Schema: steampipe.pg_catalog pg_stat_activity
# Train on Information Schema: steampipe.pg_catalog pg_stat_replication
# Train on Information Schema: steampipe.pg_catalog pg_stat_slru
# Train on Information Schema: steampipe.pg_catalog pg_stat_wal_receiver
# Train on Information Schema: steampipe.pg_catalog pg_stat_subscription
# Train on Information Schema: steampipe.pg_catalog pg_stat_ssl
# Train on Information Schema: steampipe.pg_catalog pg_stat_gssapi
# Train on Information Schema: steampipe.pg_catalog pg_replication_slots
# Train on Information Schema: steampipe.pg_catalog pg_stat_replication_slots
# Train on Information Schema: steampipe.pg_catalog pg_stat_database
# Train on Information Schema: steampipe.pg_catalog pg_stat_database_conflicts
# Train on Information Schema: steampipe.pg_catalog pg_stat_user_functions
# Train on Information Schema: steampipe.pg_catalog pg_stat_xact_user_functions
# Train on Information Schema: steampipe.pg_catalog pg_stat_archiver
# Train on Information Schema: steampipe.pg_catalog pg_stat_bgwriter
# Train on Information Schema: steampipe.pg_catalog pg_stat_wal
# Train on Information Schema: steampipe.pg_catalog pg_stat_progress_analyze
# Train on Information Schema: steampipe.pg_catalog pg_stat_progress_vacuum
# Train on Information Schema: steampipe.pg_catalog pg_stat_progress_cluster
# Train on Information Schema: steampipe.pg_catalog pg_stat_progress_create_index
# Train on Information Schema: steampipe.pg_catalog pg_stat_progress_basebackup
# Train on Information Schema: steampipe.pg_catalog pg_stat_progress_copy
# Train on Information Schema: steampipe.pg_catalog pg_user_mappings
# Train on Information Schema: steampipe.pg_catalog pg_subscription
# Train on Information Schema: steampipe.information_schema information_schema_catalog_name
# Train on Information Schema: steampipe.information_schema applicable_roles
# Train on Information Schema: steampipe.information_schema administrable_role_authorizations
# Train on Information Schema: steampipe.information_schema attributes
# Train on Information Schema: steampipe.information_schema character_sets
# Train on Information Schema: steampipe.information_schema check_constraint_routine_usage
# Train on Information Schema: steampipe.information_schema check_constraints
# Train on Information Schema: steampipe.information_schema collations
# Train on Information Schema: steampipe.information_schema collation_character_set_applicability
# Train on Information Schema: steampipe.information_schema column_column_usage
# Train on Information Schema: steampipe.information_schema column_domain_usage
# Train on Information Schema: steampipe.information_schema column_privileges
# Train on Information Schema: steampipe.information_schema column_udt_usage
# Train on Information Schema: steampipe.information_schema columns
# Train on Information Schema: steampipe.information_schema constraint_column_usage
# Train on Information Schema: steampipe.information_schema constraint_table_usage
# Train on Information Schema: steampipe.information_schema domain_constraints
# Train on Information Schema: steampipe.information_schema domain_udt_usage
# Train on Information Schema: steampipe.information_schema domains
# Train on Information Schema: steampipe.information_schema enabled_roles
# Train on Information Schema: steampipe.information_schema key_column_usage
# Train on Information Schema: steampipe.information_schema parameters
# Train on Information Schema: steampipe.information_schema referential_constraints
# Train on Information Schema: steampipe.information_schema role_column_grants
# Train on Information Schema: steampipe.information_schema routine_column_usage
# Train on Information Schema: steampipe.information_schema routine_privileges
# Train on Information Schema: steampipe.information_schema role_routine_grants
# Train on Information Schema: steampipe.information_schema routine_routine_usage
# Train on Information Schema: steampipe.information_schema routine_sequence_usage
# Train on Information Schema: steampipe.information_schema routine_table_usage
# Train on Information Schema: steampipe.information_schema routines
# Train on Information Schema: steampipe.information_schema schemata
# Train on Information Schema: steampipe.information_schema sequences
# Train on Information Schema: steampipe.information_schema sql_features
# Train on Information Schema: steampipe.information_schema sql_implementation_info
# Train on Information Schema: steampipe.information_schema sql_sizing
# Train on Information Schema: steampipe.information_schema table_constraints
# Train on Information Schema: steampipe.information_schema table_privileges
# Train on Information Schema: steampipe.information_schema role_table_grants
# Train on Information Schema: steampipe.information_schema tables
# Train on Information Schema: steampipe.information_schema triggered_update_columns
# Train on Information Schema: steampipe.information_schema triggers
# Train on Information Schema: steampipe.information_schema udt_privileges
# Train on Information Schema: steampipe.information_schema role_udt_grants
# Train on Information Schema: steampipe.information_schema usage_privileges
# Train on Information Schema: steampipe.information_schema role_usage_grants
# Train on Information Schema: steampipe.information_schema user_defined_types
# Train on Information Schema: steampipe.information_schema view_column_usage
# Train on Information Schema: steampipe.information_schema view_routine_usage
# Train on Information Schema: steampipe.information_schema view_table_usage
# Train on Information Schema: steampipe.information_schema views
# Train on Information Schema: steampipe.information_schema data_type_privileges
# Train on Information Schema: steampipe.information_schema element_types
# Train on Information Schema: steampipe.information_schema column_options
# Train on Information Schema: steampipe.information_schema foreign_data_wrapper_options
# Train on Information Schema: steampipe.information_schema foreign_data_wrappers
# Train on Information Schema: steampipe.information_schema foreign_server_options
# Train on Information Schema: steampipe.information_schema foreign_servers
# Train on Information Schema: steampipe.information_schema foreign_table_options
# Train on Information Schema: steampipe.information_schema foreign_tables
# Train on Information Schema: steampipe.information_schema user_mapping_options
# Train on Information Schema: steampipe.information_schema user_mappings
# Train on Information Schema: steampipe.steampipe_internal steampipe_settings
# Train on Information Schema: steampipe.steampipe_internal steampipe_scan_metadata
# Train on Information Schema: steampipe.steampipe_internal steampipe_plugin_limiter
# Train on Information Schema: steampipe.steampipe_internal steampipe_connection
# Train on Information Schema: steampipe.steampipe_internal steampipe_connection_state
# Train on Information Schema: steampipe.steampipe_internal steampipe_plugin
# Train on Information Schema: steampipe.steampipe_internal steampipe_server_settings
# Train on Information Schema: steampipe.steampipe_command cache
# Train on Information Schema: steampipe.steampipe_command scan_metadata
# Train on Information Schema: steampipe.steampipe steampipe_registry_plugin
# Train on Information Schema: steampipe.steampipe steampipe_registry_plugin_version
# Train on Information Schema: steampipe.public aws_rds_instance
# Train on Information Schema: steampipe.public rds_instance_without_auto_scaling
# Train on Information Schema: steampipe.aws_aw2413 aws_glacier_vault
# Train on Information Schema: steampipe.aws_aw2413 aws_guardduty_detector
# Train on Information Schema: steampipe.aws_aw2413 aws_ecr_image
# Train on Information Schema: steampipe.aws_aw2413 aws_kms_alias
# Train on Information Schema: steampipe.aws_aw2413 aws_elasticache_reserved_cache_node
# Train on Information Schema: steampipe.aws_aw2413 aws_availability_zone
# Train on Information Schema: steampipe.aws_aw2413 aws_docdb_cluster
# Train on Information Schema: steampipe.aws_aw2413 aws_kinesis_consumer
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_vpn_gateway
# Train on Information Schema: steampipe.aws_aw2413 aws_resource_explorer_search
# Train on Information Schema: steampipe.aws_aw2413 aws_identitystore_group
# Train on Information Schema: steampipe.aws_aw2413 aws_cost_forecast_monthly
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_verified_access_endpoint
# Train on Information Schema: steampipe.aws_aw2413 aws_dynamodb_metric_account_provisioned_write_capacity_util
# Train on Information Schema: steampipe.aws_aw2413 aws_ssoadmin_managed_policy_attachment
# Train on Information Schema: steampipe.aws_aw2413 aws_elasticache_replication_group
# Train on Information Schema: steampipe.aws_aw2413 aws_wellarchitected_share_invitation
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_proxy
# Train on Information Schema: steampipe.aws_aw2413 aws_region
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_group
# Train on Information Schema: steampipe.aws_aw2413 aws_media_store_container
# Train on Information Schema: steampipe.aws_aw2413 aws_elasticache_redis_metric_curr_connections_hourly
# Train on Information Schema: steampipe.aws_aw2413 aws_route53_query_log
# Train on Information Schema: steampipe.aws_aw2413 aws_redshift_snapshot
# Train on Information Schema: steampipe.aws_aw2413 aws_api_gatewayv2_stage
# Train on Information Schema: steampipe.aws_aw2413 aws_elastic_beanstalk_application
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_policy_simulator
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudtrail_channel
# Train on Information Schema: steampipe.aws_aw2413 aws_sns_topic
# Train on Information Schema: steampipe.aws_aw2413 aws_route53_traffic_policy
# Train on Information Schema: steampipe.aws_aw2413 aws_emr_cluster
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudwatch_metric_statistic_data_point
# Train on Information Schema: steampipe.aws_aw2413 aws_securityhub_standards_control
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudwatch_metric
# Train on Information Schema: steampipe.aws_aw2413 aws_inspector_assessment_template
# Train on Information Schema: steampipe.aws_aw2413 aws_config_configuration_recorder
# Train on Information Schema: steampipe.aws_aw2413 aws_wellarchitected_lens
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_nat_gateway_metric_bytes_out_to_destination
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_ssl_policy
# Train on Information Schema: steampipe.aws_aw2413 aws_securityhub_insight
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_network_load_balancer
# Train on Information Schema: steampipe.aws_aw2413 aws_oam_link
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_dhcp_options
# Train on Information Schema: steampipe.aws_aw2413 aws_ecs_cluster_metric_cpu_utilization_hourly
# Train on Information Schema: steampipe.aws_aw2413 aws_directory_service_directory
# Train on Information Schema: steampipe.aws_aw2413 aws_workspaces_workspace
# Train on Information Schema: steampipe.aws_aw2413 aws_api_gateway_api_key
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_ami_shared
# Train on Information Schema: steampipe.aws_aw2413 aws_elasticsearch_domain
# Train on Information Schema: steampipe.aws_aw2413 aws_serverlessapplicationrepository_application
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudwatch_log_subscription_filter
# Train on Information Schema: steampipe.aws_aw2413 aws_resource_explorer_index
# Train on Information Schema: steampipe.aws_aw2413 aws_ecr_repository
# Train on Information Schema: steampipe.aws_aw2413 aws_securityhub_member
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_verified_access_instance
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_target_group
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_network_load_balancer_metric_net_flow_count
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_flow_log
# Train on Information Schema: steampipe.aws_aw2413 aws_health_affected_entity
# Train on Information Schema: steampipe.aws_aw2413 aws_wafregional_web_acl
# Train on Information Schema: steampipe.aws_aw2413 aws_ecs_cluster
# Train on Information Schema: steampipe.aws_aw2413 aws_elasticache_redis_metric_new_connections_hourly
# Train on Information Schema: steampipe.aws_aw2413 aws_lambda_layer
# Train on Information Schema: steampipe.aws_aw2413 aws_backup_recovery_point
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_instance_metric_cpu_utilization
# Train on Information Schema: steampipe.aws_aw2413 aws_neptune_db_cluster_snapshot
# Train on Information Schema: steampipe.aws_aw2413 aws_emr_instance
# Train on Information Schema: steampipe.aws_aw2413 aws_sagemaker_notebook_instance
# Train on Information Schema: steampipe.aws_aw2413 aws_ecs_cluster_metric_cpu_utilization
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_application_load_balancer_metric_request_count
# Train on Information Schema: steampipe.aws_aw2413 aws_wellarchitected_notification
# Train on Information Schema: steampipe.aws_aw2413 aws_pricing_product
# Train on Information Schema: steampipe.aws_aw2413 aws_codepipeline_pipeline
# Train on Information Schema: steampipe.aws_aw2413 aws_oam_sink
# Train on Information Schema: steampipe.aws_aw2413 aws_inspector2_coverage_statistics
# Train on Information Schema: steampipe.aws_aw2413 aws_dynamodb_global_table
# Train on Information Schema: steampipe.aws_aw2413 aws_emr_instance_group
# Train on Information Schema: steampipe.aws_aw2413 aws_inspector2_finding
# Train on Information Schema: steampipe.aws_aw2413 aws_codeartifact_repository
# Train on Information Schema: steampipe.aws_aw2413 aws_elasticache_parameter_group
# Train on Information Schema: steampipe.aws_aw2413 aws_route53_record
# Train on Information Schema: steampipe.aws_aw2413 aws_msk_cluster
# Train on Information Schema: steampipe.aws_aw2413 aws_neptune_db_cluster
# Train on Information Schema: steampipe.aws_aw2413 aws_pinpoint_app
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_instance_automated_backup
# Train on Information Schema: steampipe.aws_aw2413 aws_redshift_cluster
# Train on Information Schema: steampipe.aws_aw2413 aws_globalaccelerator_endpoint_group
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudfront_origin_access_identity
# Train on Information Schema: steampipe.aws_aw2413 aws_route53_resolver_rule
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_launch_template
# Train on Information Schema: steampipe.aws_aw2413 aws_eks_addon
# Train on Information Schema: steampipe.aws_aw2413 aws_ecs_task_definition
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudformation_stack
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_ami
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_endpoint
# Train on Information Schema: steampipe.aws_aw2413 aws_acm_certificate
# Train on Information Schema: steampipe.aws_aw2413 aws_lightsail_instance
# Train on Information Schema: steampipe.aws_aw2413 aws_globalaccelerator_listener
# Train on Information Schema: steampipe.aws_aw2413 aws_guardduty_member
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_instance_metric_read_iops
# Train on Information Schema: steampipe.aws_aw2413 aws_kinesisanalyticsv2_application
# Train on Information Schema: steampipe.aws_aw2413 aws_waf_web_acl
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_nat_gateway
# Train on Information Schema: steampipe.aws_aw2413 aws_networkfirewall_firewall_policy
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_cluster_parameter_group
# Train on Information Schema: steampipe.aws_aw2413 aws_account_contact
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudfront_cache_policy
# Train on Information Schema: steampipe.aws_aw2413 aws_drs_job
# Train on Information Schema: steampipe.aws_aw2413 aws_inspector_finding
# Train on Information Schema: steampipe.aws_aw2413 aws_api_gateway_domain_name
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_cluster
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_instance_availability
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudsearch_domain
# Train on Information Schema: steampipe.aws_aw2413 aws_api_gateway_stage
# Train on Information Schema: steampipe.aws_aw2413 aws_cognito_identity_provider
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_instance_type
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_instance_metric_read_iops_hourly
# Train on Information Schema: steampipe.aws_aw2413 aws_accessanalyzer_analyzer
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_application_load_balancer_metric_request_count_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_elasticache_cluster
# Train on Information Schema: steampipe.aws_aw2413 aws_glue_job
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_instance_metric_cpu_utilization_hourly
# Train on Information Schema: steampipe.aws_aw2413 aws_mgn_application
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudwatch_log_stream
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_instance_metric_connections_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_flow_log_event
# Train on Information Schema: steampipe.aws_aw2413 aws_wellarchitected_check_detail
# Train on Information Schema: steampipe.aws_aw2413 aws_eks_cluster
# Train on Information Schema: steampipe.aws_aw2413 aws_wellarchitected_milestone
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudfront_response_headers_policy
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_instance_metric_read_iops_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_snapshot
# Train on Information Schema: steampipe.aws_aw2413 aws_account_alternate_contact
# Train on Information Schema: steampipe.aws_aw2413 aws_identitystore_group_membership
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_regional_settings
# Train on Information Schema: steampipe.aws_aw2413 aws_dms_replication_instance
# Train on Information Schema: steampipe.aws_aw2413 aws_config_conformance_pack
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudfront_function
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_managed_prefix_list
# Train on Information Schema: steampipe.aws_aw2413 aws_kinesis_stream
# Train on Information Schema: steampipe.aws_aw2413 aws_wellarchitected_workload
# Train on Information Schema: steampipe.aws_aw2413 aws_redshiftserverless_namespace
# Train on Information Schema: steampipe.aws_aw2413 aws_backup_plan
# Train on Information Schema: steampipe.aws_aw2413 aws_ecr_image_scan_finding
# Train on Information Schema: steampipe.aws_aw2413 aws_wellarchitected_consolidated_report
# Train on Information Schema: steampipe.aws_aw2413 aws_route53_traffic_policy_instance
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_launch_configuration
# Train on Information Schema: steampipe.aws_aw2413 aws_wellarchitected_answer
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudwatch_log_resource_policy
# Train on Information Schema: steampipe.aws_aw2413 aws_s3_bucket_intelligent_tiering_configuration
# Train on Information Schema: steampipe.aws_aw2413 aws_ram_principal_association
# Train on Information Schema: steampipe.aws_aw2413 aws_ssm_parameter
# Train on Information Schema: steampipe.aws_aw2413 aws_securityhub_hub
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_managed_prefix_list_entry
# Train on Information Schema: steampipe.aws_aw2413 aws_athena_query_execution
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_user
# Train on Information Schema: steampipe.aws_aw2413 aws_ssm_inventory
# Train on Information Schema: steampipe.aws_aw2413 aws_sts_caller_identity
# Train on Information Schema: steampipe.aws_aw2413 aws_codebuild_project
# Train on Information Schema: steampipe.aws_aw2413 aws_cost_forecast_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudtrail_query
# Train on Information Schema: steampipe.aws_aw2413 aws_sfn_state_machine
# Train on Information Schema: steampipe.aws_aw2413 aws_drs_recovery_snapshot
# Train on Information Schema: steampipe.aws_aw2413 aws_ssm_managed_instance_patch_state
# Train on Information Schema: steampipe.aws_aw2413 aws_appstream_fleet
# Train on Information Schema: steampipe.aws_aw2413 aws_wellarchitected_workload_share
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudcontrol_resource
# Train on Information Schema: steampipe.aws_aw2413 aws_eks_identity_provider_config
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_instance_metric_write_iops_hourly
# Train on Information Schema: steampipe.aws_aw2413 aws_lambda_function_metric_invocations_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_account_password_policy
# Train on Information Schema: steampipe.aws_aw2413 aws_config_rule
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_instance_metric_cpu_utilization_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_eks_addon_version
# Train on Information Schema: steampipe.aws_aw2413 aws_api_gateway_usage_plan
# Train on Information Schema: steampipe.aws_aw2413 aws_wafv2_web_acl
# Train on Information Schema: steampipe.aws_aw2413 aws_dynamodb_table
# Train on Information Schema: steampipe.aws_aw2413 aws_wafv2_regex_pattern_set
# Train on Information Schema: steampipe.aws_aw2413 aws_workspaces_directory
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_capacity_reservation
# Train on Information Schema: steampipe.aws_aw2413 aws_lambda_function_metric_duration_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_athena_workgroup
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_eip_address_transfer
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudfront_origin_request_policy
# Train on Information Schema: steampipe.aws_aw2413 aws_cost_usage
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_credential_report
# Train on Information Schema: steampipe.aws_aw2413 aws_organizations_account
# Train on Information Schema: steampipe.aws_aw2413 aws_codecommit_repository
# Train on Information Schema: steampipe.aws_aw2413 aws_cost_by_account_monthly
# Train on Information Schema: steampipe.aws_aw2413 aws_sfn_state_machine_execution
# Train on Information Schema: steampipe.aws_aw2413 aws_ssm_patch_baseline
# Train on Information Schema: steampipe.aws_aw2413 aws_servicequotas_default_service_quota
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_route_table
# Train on Information Schema: steampipe.aws_aw2413 aws_securityhub_finding
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_network_interface
# Train on Information Schema: steampipe.aws_aw2413 aws_config_retention_configuration
# Train on Information Schema: steampipe.aws_aw2413 aws_backup_framework
# Train on Information Schema: steampipe.aws_aw2413 aws_cost_by_tag
# Train on Information Schema: steampipe.aws_aw2413 aws_dax_parameter_group
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudwatch_log_event
# Train on Information Schema: steampipe.aws_aw2413 aws_route53_zone
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_instance_metric_cpu_utilization_hourly
# Train on Information Schema: steampipe.aws_aw2413 aws_ebs_volume_metric_read_ops_hourly
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_internet_gateway
# Train on Information Schema: steampipe.aws_aw2413 aws_codeartifact_domain
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_virtual_mfa_device
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_endpoint_service
# Train on Information Schema: steampipe.aws_aw2413 aws_service_discovery_instance
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_spot_price
# Train on Information Schema: steampipe.aws_aw2413 aws_servicecatalog_portfolio
# Train on Information Schema: steampipe.aws_aw2413 aws_appconfig_application
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_instance
# Train on Information Schema: steampipe.aws_aw2413 aws_drs_source_server
# Train on Information Schema: steampipe.aws_aw2413 aws_cost_by_record_type_monthly
# Train on Information Schema: steampipe.aws_aw2413 aws_pipes_pipe
# Train on Information Schema: steampipe.aws_aw2413 aws_inspector_assessment_target
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_access_key
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_launch_template_version
# Train on Information Schema: steampipe.aws_aw2413 aws_inspector2_coverage
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_cluster_snapshot
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_instance
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_event_subscription
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_client_vpn_endpoint
# Train on Information Schema: steampipe.aws_aw2413 aws_backup_selection
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_eip
# Train on Information Schema: steampipe.aws_aw2413 aws_elasticache_redis_metric_list_based_cmds_hourly
# Train on Information Schema: steampipe.aws_aw2413 aws_networkfirewall_firewall
# Train on Information Schema: steampipe.aws_aw2413 aws_service_discovery_service
# Train on Information Schema: steampipe.aws_aw2413 aws_glue_connection
# Train on Information Schema: steampipe.aws_aw2413 aws_glue_security_configuration
# Train on Information Schema: steampipe.aws_aw2413 aws_dynamodb_backup
# Train on Information Schema: steampipe.aws_aw2413 aws_sqs_queue
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_instance_metric_cpu_utilization_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_cognito_identity_pool
# Train on Information Schema: steampipe.aws_aw2413 aws_wellarchitected_check_summary
# Train on Information Schema: steampipe.aws_aw2413 aws_lambda_version
# Train on Information Schema: steampipe.aws_aw2413 aws_emr_instance_fleet
# Train on Information Schema: steampipe.aws_aw2413 aws_api_gatewayv2_domain_name
# Train on Information Schema: steampipe.aws_aw2413 aws_dax_subnet_group
# Train on Information Schema: steampipe.aws_aw2413 aws_glue_data_catalog_encryption_settings
# Train on Information Schema: steampipe.aws_aw2413 aws_s3_object
# Train on Information Schema: steampipe.aws_aw2413 aws_api_gateway_rest_api
# Train on Information Schema: steampipe.aws_aw2413 aws_s3_account_settings
# Train on Information Schema: steampipe.aws_aw2413 aws_sagemaker_endpoint_configuration
# Train on Information Schema: steampipe.aws_aw2413 aws_directory_service_log_subscription
# Train on Information Schema: steampipe.aws_aw2413 aws_sagemaker_model
# Train on Information Schema: steampipe.aws_aw2413 aws_ecs_cluster_metric_cpu_utilization_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_backup_vault
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_policy_attachment
# Train on Information Schema: steampipe.aws_aw2413 aws_dynamodb_table_export
# Train on Information Schema: steampipe.aws_aw2413 aws_redshift_event_subscription
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_service_specific_credential
# Train on Information Schema: steampipe.aws_aw2413 aws_sagemaker_app
# Train on Information Schema: steampipe.aws_aw2413 aws_s3_bucket
# Train on Information Schema: steampipe.aws_aw2413 aws_lambda_function_metric_errors_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_eks_node_group
# Train on Information Schema: steampipe.aws_aw2413 aws_kinesis_video_stream
# Train on Information Schema: steampipe.aws_aw2413 aws_glue_data_quality_ruleset
# Train on Information Schema: steampipe.aws_aw2413 aws_securitylake_data_lake
# Train on Information Schema: steampipe.aws_aw2413 aws_wellarchitected_lens_review
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudwatch_alarm
# Train on Information Schema: steampipe.aws_aw2413 aws_ebs_volume_metric_write_ops_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_autoscaling_group
# Train on Information Schema: steampipe.aws_aw2413 aws_resource_explorer_supported_resource_type
# Train on Information Schema: steampipe.aws_aw2413 aws_ecs_service
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_instance_metric_connections
# Train on Information Schema: steampipe.aws_aw2413 aws_guardduty_threat_intel_set
# Train on Information Schema: steampipe.aws_aw2413 aws_auditmanager_assessment
# Train on Information Schema: steampipe.aws_aw2413 aws_kinesis_firehose_delivery_stream
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudtrail_trail
# Train on Information Schema: steampipe.aws_aw2413 aws_guardduty_finding
# Train on Information Schema: steampipe.aws_aw2413 aws_glue_crawler
# Train on Information Schema: steampipe.aws_aw2413 aws_appstream_image
# Train on Information Schema: steampipe.aws_aw2413 aws_wafregional_rule
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_subnet
# Train on Information Schema: steampipe.aws_aw2413 aws_opensearch_domain
# Train on Information Schema: steampipe.aws_aw2413 aws_securityhub_standards_subscription
# Train on Information Schema: steampipe.aws_aw2413 aws_elasticache_redis_metric_cache_hits_hourly
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudwatch_log_metric_filter
# Train on Information Schema: steampipe.aws_aw2413 aws_ebs_snapshot
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_egress_only_internet_gateway
# Train on Information Schema: steampipe.aws_aw2413 aws_ecrpublic_repository
# Train on Information Schema: steampipe.aws_aw2413 aws_ecs_task
# Train on Information Schema: steampipe.aws_aw2413 aws_waf_rule
# Train on Information Schema: steampipe.aws_aw2413 aws_route53_health_check
# Train on Information Schema: steampipe.aws_aw2413 aws_securityhub_finding_aggregator
# Train on Information Schema: steampipe.aws_aw2413 aws_auditmanager_evidence
# Train on Information Schema: steampipe.aws_aw2413 aws_waf_rate_based_rule
# Train on Information Schema: steampipe.aws_aw2413 aws_eventbridge_rule
# Train on Information Schema: steampipe.aws_aw2413 aws_tagging_resource
# Train on Information Schema: steampipe.aws_aw2413 aws_eventbridge_bus
# Train on Information Schema: steampipe.aws_aw2413 aws_ssm_document_permission
# Train on Information Schema: steampipe.aws_aw2413 aws_identitystore_user
# Train on Information Schema: steampipe.aws_aw2413 aws_sns_topic_subscription
# Train on Information Schema: steampipe.aws_aw2413 aws_glue_dev_endpoint
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_option_group
# Train on Information Schema: steampipe.aws_aw2413 aws_macie2_classification_job
# Train on Information Schema: steampipe.aws_aw2413 aws_ebs_volume_metric_read_ops_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_glue_catalog_database
# Train on Information Schema: steampipe.aws_aw2413 aws_wafv2_ip_set
# Train on Information Schema: steampipe.aws_aw2413 aws_dax_parameter
# Train on Information Schema: steampipe.aws_aw2413 aws_wafv2_rule_group
# Train on Information Schema: steampipe.aws_aw2413 aws_elasticache_redis_metric_get_type_cmds_hourly
# Train on Information Schema: steampipe.aws_aw2413 aws_auditmanager_evidence_folder
# Train on Information Schema: steampipe.aws_aw2413 aws_backup_report_plan
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_transit_gateway_route_table
# Train on Information Schema: steampipe.aws_aw2413 aws_ssm_document
# Train on Information Schema: steampipe.aws_aw2413 aws_codedeploy_deployment_config
# Train on Information Schema: steampipe.aws_aw2413 aws_account
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_action
# Train on Information Schema: steampipe.aws_aw2413 aws_ebs_volume
# Train on Information Schema: steampipe.aws_aw2413 aws_auditmanager_framework
# Train on Information Schema: steampipe.aws_aw2413 aws_cost_by_record_type_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_instance_metric_connections_hourly
# Train on Information Schema: steampipe.aws_aw2413 aws_ssoadmin_permission_set
# Train on Information Schema: steampipe.aws_aw2413 aws_cost_by_service_monthly
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_reserved_db_instance
# Train on Information Schema: steampipe.aws_aw2413 aws_kms_key
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_security_group
# Train on Information Schema: steampipe.aws_aw2413 aws_redshiftserverless_workgroup
# Train on Information Schema: steampipe.aws_aw2413 aws_fsx_file_system
# Train on Information Schema: steampipe.aws_aw2413 aws_cost_by_service_usage_type_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_organizations_policy
# Train on Information Schema: steampipe.aws_aw2413 aws_route53_resolver_endpoint
# Train on Information Schema: steampipe.aws_aw2413 aws_route53_domain
# Train on Information Schema: steampipe.aws_aw2413 aws_ecs_container_instance
# Train on Information Schema: steampipe.aws_aw2413 aws_api_gatewayv2_route
# Train on Information Schema: steampipe.aws_aw2413 aws_docdb_cluster_instance
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_subnet_group
# Train on Information Schema: steampipe.aws_aw2413 aws_ssoadmin_account_assignment
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_load_balancer_listener
# Train on Information Schema: steampipe.aws_aw2413 aws_codedeploy_deployment_group
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudfront_distribution
# Train on Information Schema: steampipe.aws_aw2413 aws_wellarchitected_lens_review_report
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_transit_gateway_vpc_attachment
# Train on Information Schema: steampipe.aws_aw2413 aws_elasticache_redis_metric_engine_cpu_utilization_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_waf_rule_group
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_vpn_connection
# Train on Information Schema: steampipe.aws_aw2413 aws_guardduty_publishing_destination
# Train on Information Schema: steampipe.aws_aw2413 aws_cost_by_account_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_servicequotas_service_quota
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_reserved_instance
# Train on Information Schema: steampipe.aws_aw2413 aws_lambda_alias
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_server_certificate
# Train on Information Schema: steampipe.aws_aw2413 aws_directory_service_certificate
# Train on Information Schema: steampipe.aws_aw2413 aws_securitylake_subscriber
# Train on Information Schema: steampipe.aws_aw2413 aws_servicecatalog_product
# Train on Information Schema: steampipe.aws_aw2413 aws_sagemaker_domain
# Train on Information Schema: steampipe.aws_aw2413 aws_ebs_volume_metric_write_ops
# Train on Information Schema: steampipe.aws_aw2413 aws_securityhub_product
# Train on Information Schema: steampipe.aws_aw2413 aws_glue_catalog_table
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_network_load_balancer_metric_net_flow_count_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudtrail_import
# Train on Information Schema: steampipe.aws_aw2413 aws_redshift_subnet_group
# Train on Information Schema: steampipe.aws_aw2413 aws_codebuild_source_credential
# Train on Information Schema: steampipe.aws_aw2413 aws_guardduty_ipset
# Train on Information Schema: steampipe.aws_aw2413 aws_globalaccelerator_accelerator
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_route
# Train on Information Schema: steampipe.aws_aw2413 aws_ssm_association
# Train on Information Schema: steampipe.aws_aw2413 aws_appautoscaling_target
# Train on Information Schema: steampipe.aws_aw2413 aws_guardduty_filter
# Train on Information Schema: steampipe.aws_aw2413 aws_ssm_managed_instance_compliance
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_security_group_rule
# Train on Information Schema: steampipe.aws_aw2413 aws_backup_legal_hold
# Train on Information Schema: steampipe.aws_aw2413 aws_efs_access_point
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_account_summary
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudformation_stack_resource
# Train on Information Schema: steampipe.aws_aw2413 aws_elastic_beanstalk_environment
# Train on Information Schema: steampipe.aws_aw2413 aws_drs_recovery_instance
# Train on Information Schema: steampipe.aws_aw2413 aws_simspaceweaver_simulation
# Train on Information Schema: steampipe.aws_aw2413 aws_appautoscaling_policy
# Train on Information Schema: steampipe.aws_aw2413 aws_sagemaker_training_job
# Train on Information Schema: steampipe.aws_aw2413 aws_cost_by_service_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_ebs_volume_metric_read_ops
# Train on Information Schema: steampipe.aws_aw2413 aws_sfn_state_machine_execution_history
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_transit_gateway_route
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_parameter_group
# Train on Information Schema: steampipe.aws_aw2413 aws_health_event
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudwatch_log_group
# Train on Information Schema: steampipe.aws_aw2413 aws_servicequotas_service_quota_change_request
# Train on Information Schema: steampipe.aws_aw2413 aws_ses_domain_identity
# Train on Information Schema: steampipe.aws_aw2413 aws_inspector_exclusion
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_verified_access_group
# Train on Information Schema: steampipe.aws_aw2413 aws_s3_access_point
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_role
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_transit_gateway
# Train on Information Schema: steampipe.aws_aw2413 aws_api_gatewayv2_api
# Train on Information Schema: steampipe.aws_aw2413 aws_codedeploy_app
# Train on Information Schema: steampipe.aws_aw2413 aws_msk_serverless_cluster
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_policy
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc
# Train on Information Schema: steampipe.aws_aw2413 aws_auditmanager_control
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudwatch_metric_data_point
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_access_advisor
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_gateway_load_balancer
# Train on Information Schema: steampipe.aws_aw2413 aws_securityhub_action_target
# Train on Information Schema: steampipe.aws_aw2413 aws_cognito_user_pool
# Train on Information Schema: steampipe.aws_aw2413 aws_backup_protected_resource
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudformation_stack_set
# Train on Information Schema: steampipe.aws_aw2413 aws_organizations_policy_target
# Train on Information Schema: steampipe.aws_aw2413 aws_ssm_inventory_entry
# Train on Information Schema: steampipe.aws_aw2413 aws_wellarchitected_lens_review_improvement
# Train on Information Schema: steampipe.aws_aw2413 aws_dlm_lifecycle_policy
# Train on Information Schema: steampipe.aws_aw2413 aws_service_discovery_namespace
# Train on Information Schema: steampipe.aws_aw2413 aws_redshift_parameter_group
# Train on Information Schema: steampipe.aws_aw2413 aws_dax_cluster
# Train on Information Schema: steampipe.aws_aw2413 aws_api_gateway_authorizer
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_saml_provider
# Train on Information Schema: steampipe.aws_aw2413 aws_eks_fargate_profile
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_verified_access_trust_provider
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_customer_gateway
# Train on Information Schema: steampipe.aws_aw2413 aws_config_aggregate_authorization
# Train on Information Schema: steampipe.aws_aw2413 aws_efs_mount_target
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudtrail_trail_event
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_instance_metric_cpu_utilization
# Train on Information Schema: steampipe.aws_aw2413 aws_ssm_managed_instance
# Train on Information Schema: steampipe.aws_aw2413 aws_secretsmanager_secret
# Train on Information Schema: steampipe.aws_aw2413 aws_cost_by_service_usage_type_monthly
# Train on Information Schema: steampipe.aws_aw2413 aws_pricing_service_attribute
# Train on Information Schema: steampipe.aws_aw2413 aws_api_gatewayv2_integration
# Train on Information Schema: steampipe.aws_aw2413 aws_s3_multi_region_access_point
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_network_acl
# Train on Information Schema: steampipe.aws_aw2413 aws_wafregional_rule_group
# Train on Information Schema: steampipe.aws_aw2413 aws_amplify_app
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_instance_metric_write_iops
# Train on Information Schema: steampipe.aws_aw2413 aws_redshift_cluster_metric_cpu_utilization_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_emr_block_public_access_configuration
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_application_load_balancer
# Train on Information Schema: steampipe.aws_aw2413 aws_inspector_assessment_run
# Train on Information Schema: steampipe.aws_aw2413 aws_efs_file_system
# Train on Information Schema: steampipe.aws_aw2413 aws_elasticache_subnet_group
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_key_pair
# Train on Information Schema: steampipe.aws_aw2413 aws_rds_db_instance_metric_write_iops_daily
# Train on Information Schema: steampipe.aws_aw2413 aws_dynamodb_metric_account_provisioned_read_capacity_util
# Train on Information Schema: steampipe.aws_aw2413 aws_networkfirewall_rule_group
# Train on Information Schema: steampipe.aws_aw2413 aws_vpc_peering_connection
# Train on Information Schema: steampipe.aws_aw2413 aws_route53_resolver_query_log_config
# Train on Information Schema: steampipe.aws_aw2413 aws_elasticache_redis_metric_engine_cpu_utilization_hourly
# Train on Information Schema: steampipe.aws_aw2413 aws_cloudtrail_event_data_store
# Train on Information Schema: steampipe.aws_aw2413 aws_ec2_classic_load_balancer
# Train on Information Schema: steampipe.aws_aw2413 aws_inspector2_member
# Train on Information Schema: steampipe.aws_aw2413 aws_ssm_maintenance_window
# Train on Information Schema: steampipe.aws_aw2413 aws_wellarchitected_lens_share
# Train on Information Schema: steampipe.aws_aw2413 aws_lambda_function
# Train on Information Schema: steampipe.aws_aw2413 aws_ses_email_identity
# Train on Information Schema: steampipe.aws_aw2413 aws_ebs_volume_metric_write_ops_hourly
# Train on Information Schema: steampipe.aws_aw2413 aws_iam_open_id_connect_provider
# Train on Information Schema: steampipe.aws_aw2413 aws_emr_cluster_metric_is_idle
# Train on Information Schema: steampipe.aws_aw2413 aws_lambda_layer_version
# Train on Information Schema: steampipe.aws_aw2413 aws_ssoadmin_instance
# Train on Information Schema: steampipe.aws_aw2413 aws_ram_resource_association
# Train on Information Schema: steampipe.aws_aw2413 aws_codebuild_build

# %%
vn.train(documentation=""""
         You are a helpful AI assistant expert in querying SQL Database to find sql query of user query in normal english.

Your Job:
1) You are expert in creating SQL Query for Postgres. Based on user query, create a SQL Query to fetch data from Postgres DB.
2) Your job is to convert TEXT to SQL Query.
3) Your job is to only give SQL Query. You don't need to execute it. We will execute it on our end. So please make sure that your SQL Query is correct. 
4) Your job is to only give one sql query. dont write any other text or information.
5) You can also add joins between two tables based for columns names. For example, if user query is "List of EC2 instances provisioned with undesired instance type", then you can add join between aws_ec2_instance and aws_ec2_instance_metric_cpu_utilization table based on column name "instance_id" and "instance_id" respectively.
6) Query will be run as postgres_fdw so create accordingly.

About EC2 Instances in AWS:
The AWS EC2 Instance is a virtual server in Amazon's Elastic Compute Cloud (EC2) for running applications on the Amazon Web Services (AWS) infrastructure. It provides scalable computing capacity in the AWS cloud, eliminating the need to invest in hardware up front, so you can develop and deploy applications faster. With EC2, you can launch as many or as few virtual servers as you need, configure security and networking, and manage storage.

Instructions to Create SQL Query:
1) Here are the Table names based on EC2 instances and their corresponding column name, its datatype and the description about the columns.
2) Make sure you understand the column descriptions to create SQL query that is meant to solve User Query

Amazon EC2 Tables:


1) Table: aws_ec2_instance - Query AWS EC2 Instances using SQL#
Table Usage Guide:
The aws_ec2_instance table in Steampipe provides you with information about EC2 Instances within AWS Elastic Compute Cloud (EC2). This table allows you, as a DevOps engineer, to query instance-specific details, including instance state, launch time, instance type, and associated metadata. You can utilize this table to gather insights on instances, such as instances with specific tags, instances in a specific state, instances of a specific type, and more. The schema outlines the various attributes of the EC2 instance for you, including the instance ID, instance state, instance type, and associated tags.


Schema for aws_ec2_instance:

Name	Type	Operators	Description
_ctx	jsonb		Steampipe context in JSON form, e.g. connection_name.
account_id	text		The AWS Account ID in which the resource is located.
akas	jsonb		Array of globally unique identifier strings (also known as) for the resource.
ami_launch_index	bigint		The AMI launch index, which can be used to find this instance in the launch group.
architecture	text		The architecture of the image.
arn	text		The Amazon Resource Name (ARN) specifying the instance.
block_device_mappings	jsonb		Block device mapping entries for the instance.
boot_mode	text		The boot mode of the instance.
capacity_reservation_id	text		The ID of the Capacity Reservation.
capacity_reservation_specification	jsonb		Information about the Capacity Reservation targeting option.
client_token	text		The idempotency token you provided when you launched the instance, if applicable.
cpu_options_core_count	bigint		The number of CPU cores for the instance.
cpu_options_threads_per_core	bigint		The number of threads per CPU core.
disable_api_termination	boolean		If the value is true, instance can't be terminated through the Amazon EC2 console, CLI, or API.
ebs_optimized	boolean		Indicates whether the instance is optimized for Amazon EBS I/O. This optimization provides dedicated throughput to Amazon EBS and an optimized configuration stack to provide optimal I/O performance. This optimization isn't available with all instance types.
elastic_gpu_associations	jsonb		The Elastic GPU associated with the instance.
elastic_inference_accelerator_associations	jsonb		The elastic inference accelerator associated with the instance.
ena_support	boolean		Specifies whether enhanced networking with ENA is enabled.
enclave_options	jsonb		Indicates whether the instance is enabled for Amazon Web Services Nitro Enclaves.
hibernation_options	jsonb		Indicates whether the instance is enabled for hibernation.
hypervisor	text	=	The hypervisor type of the instance. The value xen is used for both Xen and Nitro hypervisors.
iam_instance_profile_arn	text	=	The Amazon Resource Name (ARN) of IAM instance profile associated with the instance, if applicable.
iam_instance_profile_id	text		The ID of the instance profile associated with the instance, if applicable.
image_id	text	=	The ID of the AMI used to launch the instance.
instance_id	text	=	The ID of the instance.
instance_initiated_shutdown_behavior	text		Indicates whether an instance stops or terminates when you initiate shutdown from the instance (using the operating system command for system shutdown).
instance_lifecycle	text	=	Indicates whether this is a spot instance or a scheduled instance.
instance_state	text	=	The state of the instance (pending | running | shutting-down | terminated | stopping | stopped).
instance_status	jsonb		The status of an instance. Instance status includes scheduled events, status checks and instance state information.
instance_type	text	=	The instance type.
kernel_id	text		The kernel ID
key_name	text		The name of the key pair, if this instance was launched with an associated key pair.
launch_template_data	jsonb		The configuration data of the specified instance.
launch_time	timestamp with time zone		The time the instance was launched.
licenses	jsonb		The license configurations for the instance.
maintenance_options	jsonb		The metadata options for the instance.
metadata_options	jsonb		The metadata options for the instance.
monitoring_state	text	=	Indicates whether detailed monitoring is enabled (disabled | enabled).
network_interfaces	jsonb		The network interfaces for the instance.
outpost_arn	text	=	The Amazon Resource Name (ARN) of the Outpost, if applicable.
partition	text		The AWS partition in which the resource is located (aws, aws-cn, or aws-us-gov).
placement_affinity	text		The affinity setting for the instance on the Dedicated Host.
placement_availability_zone	text	=	The Availability Zone of the instance.
placement_group_id	text		The ID of the placement group that the instance is in.
placement_group_name	text	=	The name of the placement group the instance is in.
placement_host_id	text		The ID of the Dedicated Host on which the instance resides.
placement_host_resource_group_arn	text		The ARN of the host resource group in which to launch the instances.
placement_partition_number	bigint		The ARN of the host resource group in which to launch the instances.
placement_tenancy	text	=	The tenancy of the instance (if the instance is running in a VPC). An instance with a tenancy of dedicated runs on single-tenant hardware.
platform	text		The value is 'Windows' for Windows instances; otherwise blank.
platform_details	text		The platform details value for the instance.
private_dns_name	text		The private DNS hostname name assigned to the instance. This DNS hostname can only be used inside the Amazon EC2 network. This name is not available until the instance enters the running state.
private_dns_name_options	jsonb		The options for the instance hostname.
private_ip_address	inet		The private IPv4 address assigned to the instance.
product_codes	jsonb		The product codes attached to this instance, if applicable.
public_dns_name	text	=	The public DNS name assigned to the instance. This name is not available until the instance enters the running state.
public_ip_address	inet		The public IPv4 address, or the Carrier IP address assigned to the instance, if applicable.
ram_disk_id	text	=	The RAM disk ID.
region	text		The AWS Region in which the resource is located.
root_device_name	text	=	The device name of the root device volume (for example, /dev/sda1).
root_device_type	text	=	The root device type used by the AMI. The AMI can use an EBS volume or an instance store volume.
security_groups	jsonb		The security groups for the instance.
source_dest_check	boolean		Specifies whether to enable an instance launched in a VPC to perform NAT. This controls whether source/destination checking is enabled on the instance.
spot_instance_request_id	text		If the request is a Spot Instance request, the ID of the request.
sriov_net_support	text		Indicates whether enhanced networking with the Intel 82599 Virtual Function interface is enabled.
state_code	bigint		The reason code for the state change.
state_transition_reason	text		The reason for the most recent state transition.
state_transition_time	timestamp with time zone		The date and time, the instance state was last modified.
subnet_id	text	=	The ID of the subnet in which the instance is running.
tags	jsonb		A map of tags for the resource.
tags_src	jsonb		A list of tags assigned to the instance.
title	text		Title of the resource.
tpm_support	text		If the instance is configured for NitroTPM support, the value is v2.0.
usage_operation	text		The usage operation value for the instance.
usage_operation_update_time	text		The time that the usage operation was last updated.
user_data	text		The user data of the instance.
virtualization_type	text	=	The virtualization type of the instance.
vpc_id	text	=	The ID of the VPC in which the instance is running.


2) Table: aws_ec2_instance_metric_cpu_utilization - Query AWS EC2 Instance Metrics using SQL

Table Usage Guide:
The aws_ec2_instance_metric_cpu_utilization table in Steampipe provides you with information about CPU utilization metrics of EC2 instances within AWS CloudWatch. This table allows you, as a DevOps engineer, system administrator, or other technical professional, to query CPU-specific details, including the instance's average, maximum, and minimum CPU utilization. You can utilize this table to gather insights on instance performance, such as identifying instances with high CPU utilization, analyzing CPU usage patterns, and more. The schema outlines the various attributes of the EC2 instance CPU utilization metrics for you, including the instance ID, namespace, metric name, and statistics.Format: 


Schema for aws_ec2_instance_metric_cpu_utilization:
Name	Type	Operators	Description
_ctx	jsonb		Steampipe context in JSON form, e.g. connection_name.
account_id	text		The AWS Account ID in which the resource is located.
average	double precision		The average of the metric values that correspond to the data point.
instance_id	text		The ID of the instance.
maximum	double precision		The maximum metric value for the data point.
metric_name	text		The name of the metric.
minimum	double precision		The minimum metric value for the data point.
namespace	text		The metric namespace.
partition	text		The AWS partition in which the resource is located (aws, aws-cn, or aws-us-gov).
region	text		The AWS Region in which the resource is located.
sample_count	double precision		The number of metric values that contributed to the aggregate value of this data point.
sum	double precision		The sum of the metric values for the data point.
timestamp	timestamp with time zone		The time stamp used for the data point.
unit	text		The standard unit for the data point.


3) Table: aws_ec2_instance_metric_cpu_utilization_daily - Query AWS EC2 Instances using SQL

Table Usage Guide:
The aws_ec2_instance_metric_cpu_utilization_daily table in Steampipe provides you with information about the daily CPU utilization metrics of AWS EC2 instances. This table allows you, as a DevOps engineer, to query instance-specific details, including average, maximum, and minimum CPU utilization, and associated timestamps. You can utilize this table to gather insights on CPU usage patterns over time, such as instances with high or low CPU utilization, instances with abnormal CPU usage patterns, and more. The schema outlines the various attributes of the CPU utilization metrics for you, including the instance ID, timestamp, average CPU utilization, maximum CPU utilization, and minimum CPU utilization.The aws_ec2_instance_metric_cpu_utilization_daily table provides you with metric statistics at 24 hour intervals for the last year.

Schema for aws_ec2_instance_metric_cpu_utilization_daily:

Name	Type	Operators	Description
_ctx	jsonb		Steampipe context in JSON form, e.g. connection_name.
account_id	text		The AWS Account ID in which the resource is located.
average	double precision		The average of the metric values that correspond to the data point.
instance_id	text		The ID of the instance.
maximum	double precision		The maximum metric value for the data point.
metric_name	text		The name of the metric.
minimum	double precision		The minimum metric value for the data point.
namespace	text		The metric namespace.
partition	text		The AWS partition in which the resource is located (aws, aws-cn, or aws-us-gov).
region	text		The AWS Region in which the resource is located.
sample_count	double precision		The number of metric values that contributed to the aggregate value of this data point.
sum	double precision		The sum of the metric values for the data point.
timestamp	timestamp with time zone		The time stamp used for the data point.
unit	text		The standard unit for the data point.

User Query: ﻿List of EC2 instances provisioned with undesired(for example t2.large and m3.medium is desired) instance type(s)﻿
         """)

vn.train(sql="select instance_id, instance_state, launch_time, state_transition_time from aws_ec2_instance where instance_state = 'stopped' and state_transition_time <= (current_date - interval '30' day);")
vn.train(sql="select instance_id, monitoring_state from aws_ec2_instance where monitoring_state = 'disabled';")
vn.train(sql="select instance_type, count(instance_type) as count from aws_ec2_instance group by instance_type;")
# Out:
# Adding documentation....
# Question generated with sql: What are the instance IDs, instance states, launch times, and state transition times of the instances that have been stopped for more than 30 days?
# Adding SQL...
# Question generated with sql: What are the instance IDs and monitoring states of the disabled instances?
# Adding SQL...
# Question generated with sql: What are the counts of each type of instance in the AWS EC2 environment?
# Adding SQL...
# ''

# %%
training_data = vn.get_training_data()
print(training_data)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from vanna.flask import VannaFlaskApp
app = VannaFlaskApp(vn)
app.run()
# Out:
# Your app is running at:
# http://localhost:8084
#  * Serving Flask app 'vanna.flask'
#  * Debug mode: off
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Exception in thread Thread-37 (process_request_thread):
# Traceback (most recent call last):
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/vanna/base/base.py", line 368, in run_sql_postgres
#     cs.execute(sql)
# psycopg2.errors.UndefinedTable: relation "your_table_name" does not exist
# LINE 2: FROM your_table_name
#              ^
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/socketserver.py", line 683, in process_request_thread
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.10/socketserver.py", line 360, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.10/socketserver.py", line 747, in __init__
#     self.handle()
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/werkzeug/serving.py", line 390, in handle
#     super().handle()
#   File "/usr/lib/python3.10/http/server.py", line 433, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.10/http/server.py", line 421, in handle_one_request
#     method()
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/werkzeug/serving.py", line 362, in run_wsgi
#     execute(self.server.app)
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/werkzeug/serving.py", line 323, in execute
#     application_iter = app(environ, start_response)
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/flask/app.py", line 1478, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/flask/app.py", line 1455, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/flask/app.py", line 867, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/flask/app.py", line 852, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/vanna/flask.py", line 89, in decorated
#     return f(*args, **field_values, **kwargs)
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/vanna/flask.py", line 191, in run_sql
#     df = vn.run_sql(sql=sql)
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/vanna/base/base.py", line 379, in run_sql_postgres
#     raise ValidationError(e)
# vanna.exceptions.ValidationError: relation "your_table_name" does not exist
# LINE 2: FROM your_table_name
#              ^
#
# Exception in thread Thread-39 (process_request_thread):
# Traceback (most recent call last):
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/vanna/base/base.py", line 368, in run_sql_postgres
#     cs.execute(sql)
# psycopg2.errors.UndefinedTable: relation "your_table" does not exist
# LINE 2: FROM your_table
#              ^
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/socketserver.py", line 683, in process_request_thread
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.10/socketserver.py", line 360, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.10/socketserver.py", line 747, in __init__
#     self.handle()
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/werkzeug/serving.py", line 390, in handle
#     super().handle()
#   File "/usr/lib/python3.10/http/server.py", line 433, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.10/http/server.py", line 421, in handle_one_request
#     method()
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/werkzeug/serving.py", line 362, in run_wsgi
#     execute(self.server.app)
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/werkzeug/serving.py", line 323, in execute
#     application_iter = app(environ, start_response)
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/flask/app.py", line 1478, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/flask/app.py", line 1455, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/flask/app.py", line 867, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/flask/app.py", line 852, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/vanna/flask.py", line 89, in decorated
#     return f(*args, **field_values, **kwargs)
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/vanna/flask.py", line 191, in run_sql
#     df = vn.run_sql(sql=sql)
#   File "/home/imabhisht/.pyenv/versions/lookover-cg/lib/python3.10/site-packages/vanna/base/base.py", line 379, in run_sql_postgres
#     raise ValidationError(e)
# vanna.exceptions.ValidationError: relation "your_table" does not exist
# LINE 2: FROM your_table
#              ^
